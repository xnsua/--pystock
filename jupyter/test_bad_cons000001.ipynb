# %%
import datetime
import pandas
df = pandas.read_csv('~/ModelResult/Bad/com000001.csv', encoding='utf-8')
(df)
# Out:
#          index  name  dropdays  base_yield     yield  base_yyield     yyield
# 0     sh600000  浦发银行         2   14.141843  1.132080     1.238003   1.094971
# 1     sh600004  白云机场         2    3.907138  1.513625     1.116090   1.362903
# 2     sh600006  东风汽车         2    2.890610  0.595213     1.089312   0.679521
# 3     sh600007  中国国贸         2    5.769827  4.019445     1.151712   2.693349
# 4     sh600008  首创股份         2    5.174088  0.724253     1.141641   0.787577
# 5     sh600009  上海机场         2    3.561976  0.824015     1.107801   0.882674
# 6     sh600010  包钢股份         2    4.176670  0.822582     1.122106   0.862702
# 7     sh600011  华能国际         2    2.092930  1.635889     1.061330   1.415537
# 8     sh600012  皖通高速         2    4.530053  1.077345     1.129475   1.056169
# 9     sh600015  华夏银行         2    7.425306  1.581616     1.175365   1.394180
# 10    sh600016  民生银行         2    8.319101  1.743859     1.186181   1.489404
# ...

# %%
df = df.assign(win = df.yyield > df.base_yyield)
df1 = df[df.dropdays == 1]
df2 = df[df.dropdays == 2]
df3 = df[df.dropdays == 3]

# %%
df1
# Out:
#        index      name  dropdays  base_yield     yield  base_yyield    yyield  \
# 0   sh000001      上证指数         1    2.544821  0.487464     1.078184  0.800244
# 1   sh000010     上证180         1    3.358556  0.756401     1.102564  0.918347
# 2   sh000016      上证50         1    3.032485  0.467078     1.093526  0.793650
# 3   sh000009     上证380         1    6.380655  0.334081     1.161090  0.694224
# 4   sh000300     沪深300         1    3.667119  0.844372     1.110402  0.949204
# 5   sz399001      深证成指         1    3.455169  0.329446     1.105087  0.706505
# 6   sz399004    深证100R         1    5.113454  0.264078     1.140556  0.657503
# 7   sz399005      中小板指         1    0.032400  0.273308     0.751558  0.624054
# 8   sh000015      红利指数         1    2.855536  0.593726     1.088240  0.846782
# 9   sz399922      中证红利         1    1.180950  0.531741     1.018525  0.752427
# 10  sh000905  中证500(沪)         1    6.242254  0.427520     1.159040  0.752456
#
#       win
# 0   False
# ...

# %%
df2
# Out:
#          index  name  dropdays  base_yield     yield  base_yyield     yyield  \
# 0     sh600000  浦发银行         2   14.141843  1.132080     1.238003   1.094971
# 1     sh600004  白云机场         2    3.907138  1.513625     1.116090   1.362903
# 2     sh600006  东风汽车         2    2.890610  0.595213     1.089312   0.679521
# 3     sh600007  中国国贸         2    5.769827  4.019445     1.151712   2.693349
# 4     sh600008  首创股份         2    5.174088  0.724253     1.141641   0.787577
# 5     sh600009  上海机场         2    3.561976  0.824015     1.107801   0.882674
# 6     sh600010  包钢股份         2    4.176670  0.822582     1.122106   0.862702
# 7     sh600011  华能国际         2    2.092930  1.635889     1.061330   1.415537
# 8     sh600012  皖通高速         2    4.530053  1.077345     1.129475   1.056169
# 9     sh600015  华夏银行         2    7.425306  1.581616     1.175365   1.394180
# 10    sh600016  民生银行         2    8.319101  1.743859     1.186181   1.489404
# ...

# %%
print(len(df2[df2.win==True]))
print(count(df2winlist, True))
# Out:
# 1024
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-0220700f5ede> in <module>()
#       1 print(len(df2[df2.win==True]))
# ----> 2 print(count(df2winlist, True))
#
# NameError: name 'count' is not defined

# %%
df3
# Out:
#        index      name  dropdays  base_yield     yield  base_yyield    yyield  \
# 22  sh000001      上证指数         3    2.544821  0.700292     1.078184  0.505655
# 23  sh000010     上证180         3    3.358556  0.683057     1.102564  0.510759
# 24  sh000016      上证50         3    3.032485  0.785214     1.093526  0.673721
# 25  sh000009     上证380         3    6.380655  0.626801     1.161090  0.369656
# 26  sh000300     沪深300         3    3.667119  0.691607     1.110402  0.526916
# 27  sz399001      深证成指         3    3.455169  0.524596     1.105087  0.328548
# 28  sz399004    深证100R         3    5.113454  0.572490     1.140556  0.389683
# 29  sz399005      中小板指         3    0.032400  0.701845     0.751558  0.510479
# 30  sh000015      红利指数         3    2.855536  0.774462     1.088240  0.645395
# 31  sz399922      中证红利         3    1.180950  0.774749     1.018525  0.554391
# 32  sh000905  中证500(沪)         3    6.242254  0.563988     1.159040  0.288880
#
#       win
# 22  False
# ...
